# %% [markdown]
# # Concept Session
# ## You might have noticed that data is present in multiple files in the dataset provided to you. What is the first thing that comes to your mind?
# ## 'Merge them'

# %% [markdown]
# ## You may need to bring all the data at one place by some sort of join logic and then start your analysis.

# %% [markdown]
# # Task-1)

# %% [markdown]
# ## Assume that you have some data of customers with Cust_ID in one sheet of an excel file and some more data with Cust_ID in a second sheet of the same excel file. How can you join these data?
# ### Read data from first sheet of excel file 'customer.xlsx'

# %%
#Reading data from excel file
import pandas as pd
df_cust1 = pd.read_excel('customer.xlsx', sheet_name=0)
df_cust1
# Out:
#    Cust_ID      Name
# 0      101    Olivia
# 1      102  Will LLC
# 2      103    Sophia
# 3      104  Isabella

# %% [markdown]
# ### Read the data from second sheet of excel file.

# %%
#Reading data from excel file
df_cust2 = pd.read_excel('customer.xlsx', sheet_name=1)
df_cust2
# Out:
#    Order_ID  Cust_ID  Order
# 0       222      101    789
# 1       223      102    465
# 2       224      103    674
# 3       225      104    564
# 4       226      105    589

# %% [markdown]
# ## 1. Inner Join

# %%
#inner join - use intersection of index observed in both dataframes
df_cust1.set_index('Cust_ID').join(df_cust2.set_index('Cust_ID'), on='Cust_ID', how='inner')
# Out:
#              Name  Order_ID  Order
# Cust_ID
# 101        Olivia       222    789
# 102      Will LLC       223    465
# 103        Sophia       224    674
# 104      Isabella       225    564

# %% [markdown]
# ## 2. Outer Join

# %%
#outer join - use union of index observed in both dataframes
df_cust1.set_index('Cust_ID').join(df_cust2.set_index('Cust_ID'), on='Cust_ID', how='outer')
# Out:
#        Cust_ID      Name  Order_ID  Order
# 101.0      101    Olivia       222    789
# 102.0      102  Will LLC       223    465
# 103.0      103    Sophia       224    674
# 104.0      104  Isabella       225    564
# NaN        105       NaN       226    589

# %% [markdown]
# ## 3. Right Join

# %%
#right join - use only the index found in right dataframes
df_cust1.set_index('Cust_ID').join(df_cust2.set_index('Cust_ID'), on='Cust_ID', how='right')
# Out:
#        Cust_ID      Name  Order_ID  Order
# 101.0      101    Olivia       222    789
# 102.0      102  Will LLC       223    465
# 103.0      103    Sophia       224    674
# 104.0      104  Isabella       225    564
# NaN        105       NaN       226    589

# %% [markdown]
# ## 4. Left Join

# %%
#left join - use only the index found in left dataframes
df_cust1.set_index('Cust_ID').join(df_cust2.set_index('Cust_ID'), on='Cust_ID', how='left')
# Out:
#              Name  Order_ID  Order
# Cust_ID
# 101        Olivia       222    789
# 102      Will LLC       223    465
# 103        Sophia       224    674
# 104      Isabella       225    564

# %% [markdown]
# # Task-2)

# %% [markdown]
# ## Assume that you have some data of customers with Cust_ID in one sheet of an excel file and some more data with Cust_ID in a second sheet of same excel file. How can you join these data?
# ### Read data from first sheet of excel file 'Ecommerce_data.xlsx'

# %%
#Reading data from excel file
df_cust = pd.read_excel('Ecommerce_data.xlsx', sheet_name=0)
df_cust
# Out:
#   Cust_ID  Age  Gender     City
# 0  Cust_1   35    Male   Mumbai
# 1  Cust_2   24  Female  Chennai
# 2  Cust_3   20  Female    Delhi
# 3  Cust_4   45    Male  Chennai
# 4  Cust_5   37    Male   Mumbai
# 5  Cust_6   40  Female   Mumbai

# %% [markdown]
# ### Read data from second sheet of excel file

# %%
df_order = pd.read_excel('Ecommerce_data.xlsx', sheet_name=1)
df_order
# Out:
#    Ord_ID  Cust_ID  Ord_quantity      Sales Ord_priority
# 0  Ord_10   Cust_1           4.0  3237.0000       Medium
# 1  Ord_14   Cust_2           NaN        NaN          NaN
# 2  Ord_25   Cust_3           2.0   422.7000          Low
# 3  Ord_29   Cust_4          15.0  4571.7900         High
# 4  Ord_34   Cust_5           8.0  4233.1500          Low
# 5  Ord_52   Cust_6           3.0   164.0200         High
# 6  Ord_71  Cust_11           1.0   147.6400          Low
# 7  Ord_94   Cust_8           7.0  3410.1575       Medium

# %% [markdown]
# ## 1. Inner Merge

# %%
#Merging dataframe on common customer_ID
pd.merge(df_cust, df_order, on='Cust_ID')
#merges the common data only
# Out:
#   Cust_ID  Age  Gender     City  Ord_ID  Ord_quantity    Sales Ord_priority
# 0  Cust_1   35    Male   Mumbai  Ord_10           4.0  3237.00       Medium
# 1  Cust_2   24  Female  Chennai  Ord_14           NaN      NaN          NaN
# 2  Cust_3   20  Female    Delhi  Ord_25           2.0   422.70          Low
# 3  Cust_4   45    Male  Chennai  Ord_29          15.0  4571.79         High
# 4  Cust_5   37    Male   Mumbai  Ord_34           8.0  4233.15          Low
# 5  Cust_6   40  Female   Mumbai  Ord_52           3.0   164.02         High

# %% [markdown]
# ## 2. Outer Merge

# %%
#Outer merge
pd.merge(df_cust, df_order, on='Cust_ID', how='outer')
#merges every thing frm both the data.

# If we different column names in two data frames and if we want to merge....
# use left_on and right_on parameters of merge function
# Out:
#    Cust_ID   Age  Gender     City  Ord_ID  Ord_quantity      Sales  \
# 0   Cust_1  35.0    Male   Mumbai  Ord_10           4.0  3237.0000
# 1   Cust_2  24.0  Female  Chennai  Ord_14           NaN        NaN
# 2   Cust_3  20.0  Female    Delhi  Ord_25           2.0   422.7000
# 3   Cust_4  45.0    Male  Chennai  Ord_29          15.0  4571.7900
# 4   Cust_5  37.0    Male   Mumbai  Ord_34           8.0  4233.1500
# 5   Cust_6  40.0  Female   Mumbai  Ord_52           3.0   164.0200
# 6  Cust_11   NaN     NaN      NaN  Ord_71           1.0   147.6400
# 7   Cust_8   NaN     NaN      NaN  Ord_94           7.0  3410.1575
#
#   Ord_priority
# 0       Medium
# 1          NaN
# 2          Low
# 3         High
# 4          Low
# 5         High
# 6          Low
# 7       Medium

# %% [markdown]
# ## 3. Right Merge

# %%
#Right merge
pd.merge(df_cust, df_order, on='Cust_ID', how='right')
# Out:
#    Cust_ID   Age  Gender     City  Ord_ID  Ord_quantity      Sales  \
# 0   Cust_1  35.0    Male   Mumbai  Ord_10           4.0  3237.0000
# 1   Cust_2  24.0  Female  Chennai  Ord_14           NaN        NaN
# 2   Cust_3  20.0  Female    Delhi  Ord_25           2.0   422.7000
# 3   Cust_4  45.0    Male  Chennai  Ord_29          15.0  4571.7900
# 4   Cust_5  37.0    Male   Mumbai  Ord_34           8.0  4233.1500
# 5   Cust_6  40.0  Female   Mumbai  Ord_52           3.0   164.0200
# 6  Cust_11   NaN     NaN      NaN  Ord_71           1.0   147.6400
# 7   Cust_8   NaN     NaN      NaN  Ord_94           7.0  3410.1575
#
#   Ord_priority
# 0       Medium
# 1          NaN
# 2          Low
# 3         High
# 4          Low
# 5         High
# 6          Low
# 7       Medium

# %% [markdown]
# ## 4. Right Merge

# %%
#Left merge
pd.merge(df_cust, df_order, on='Cust_ID', how='left')
# Out:
#   Cust_ID  Age  Gender     City  Ord_ID  Ord_quantity    Sales Ord_priority
# 0  Cust_1   35    Male   Mumbai  Ord_10           4.0  3237.00       Medium
# 1  Cust_2   24  Female  Chennai  Ord_14           NaN      NaN          NaN
# 2  Cust_3   20  Female    Delhi  Ord_25           2.0   422.70          Low
# 3  Cust_4   45    Male  Chennai  Ord_29          15.0  4571.79         High
# 4  Cust_5   37    Male   Mumbai  Ord_34           8.0  4233.15          Low
# 5  Cust_6   40  Female   Mumbai  Ord_52           3.0   164.02         High

# %% [markdown]
# # Task-3)

# %% [markdown]
# ## Represent the name of some persons with their date of births in a tabular format.

# %%
#from datetime import date                                      # Import function
df = pd.DataFrame({                                            # Define entires
    'name': ['alice','bob','charlie'],
    'date_of_birth': ['10/25/2005','10/29/2002','01/01/2001']
})
df['date_of_birth'] = pd.to_datetime(df['date_of_birth'])      # convert to type datetime
df                                                             # print output
# Out:
#       name date_of_birth
# 0    alice    2005-10-25
# 1      bob    2002-10-29
# 2  charlie    2001-01-01

# %% [markdown]
# # Dataset: Insurance Claim
# # File name: 'insurance_data_with_day.csv'
# ## Read the data from this file and perform the following computations.

# %% [markdown]
# # Task-4)

# %% [markdown]
# ## Find the duplicate rows except their first occurence in the dataset.

# %%
#Reading data from csv file
df = pd.read_csv('insurance_data_with_day.csv')
df.head()
# Out:
#    patientid  dayofmonth  age gender   bmi  bloodpressure diabetic  children  \
# 0          1          19   39   male  23.2             91      Yes         0
# 1          2           8   24   male  30.1             87       No         0
# 2          3          11   27   male  33.3             82      Yes         0
# 3          4           5   37   male  33.7             80       No         0
# 4          5          21   30   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %%
df.shape
# Out:
# (1340, 11)

# %%
df.duplicated(keep=False) #keep=False marks all duplicate row as true
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1335    False
# 1336    False
# 1337    False
# 1338    False
# 1339    False
# Length: 1340, dtype: bool

# %%
#Retrieve only duplicate rows
#Let's not consider the patientid from dataframe
df1 = df.loc[:,df.columns!='patientid']
#Select all duplicate rows except their first occurence
df_dup = df1[df1.duplicated(keep='first')]
df_dup
# Out:
#    dayofmonth  age gender   bmi  bloodpressure diabetic  children smoker  \
# 9           1   29   male  37.3             86      Yes         0     No
#
#       region    claim
# 9  northwest  1141.45

# %% [markdown]
# # Task-5)

# %% [markdown]
# ## Find the duplicate rows based on the columns of age, gender and blood pressure.

# %%
# Find duplicated rows based on given columns except their first occurence
df_dup1 = df1[df1.duplicated(['age','gender','bloodpressure'], keep='first')]
df_dup1
# Out:
#       dayofmonth  age  gender   bmi  bloodpressure diabetic  children smoker  \
# 9              1   29    male  37.3             86      Yes         0     No
# 48            23   34    male  16.0             83       No         0     No
# 60            25   49    male  35.2             80      Yes         1     No
# 83             3   43    male  36.9             91      Yes         0     No
# 84             8   36    male  22.0             88      Yes         1     No
# ...          ...  ...     ...   ...            ...      ...       ...    ...
# 1309          13   47  female  43.9            104       No         2    Yes
# 1314          23   22    male  33.9             97       No         0    Yes
# 1319          10   40    male  36.3             94      Yes         1    Yes
# 1335          27   44  female  35.5             88      Yes         0    Yes
# 1337          27   30    male  34.5             91      Yes         3    Yes
#
#          region     claim
# ...

# %%
# Keep=False will select all duplicate rows
df_dup1 = df1[df1.duplicated(['age','gender','bloodpressure'], keep=False)]
df_dup1
# Out:
#       dayofmonth  age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0             19   39    male  23.2             91      Yes         0     No
# 2             11   27    male  33.3             82      Yes         0     No
# 4             21   30    male  34.1            100       No         0     No
# 5             16   47    male  34.4             96      Yes         0     No
# 6              1   29    male  37.3             86      Yes         0     No
# ...          ...  ...     ...   ...            ...      ...       ...    ...
# 1309          13   47  female  43.9            104       No         2    Yes
# 1314          23   22    male  33.9             97       No         0    Yes
# 1319          10   40    male  36.3             94      Yes         1    Yes
# 1335          27   44  female  35.5             88      Yes         0    Yes
# 1337          27   30    male  34.5             91      Yes         3    Yes
#
#          region     claim
# ...

# %% [markdown]
# # Task-6)

# %% [markdown]
# ## Drop the duplicate rows where column matches.

# %%
print(df1.shape)
df_drop_duplicate = df1.drop_duplicates()
print(df_drop_duplicate.shape)
# Out:
# (1340, 10)
# (1339, 10)

# %% [markdown]
# # Task-7)

# %% [markdown]
# ## Drop the duplicate rows except their first occurence based on the columns of age, gender, bmi and children.

# %%
print(df1.shape)
#Finding duplicate rows based on the columns of 'age','gender','bmi','children'
df_duplicate_by_col = df1[df1.duplicated(['age','gender','bmi','children'], keep=False)]
df_duplicate_by_col.shape
# Out:
# (1340, 10)
# (31, 10)

# %%
df_duplicate_by = df_duplicate_by_col.drop_duplicates(subset=['age','gender','bmi','children'], keep='first')
df_duplicate_by
# Out:
#       dayofmonth  age  gender   bmi  bloodpressure diabetic  children smoker  \
# 6              1   29    male  37.3             86      Yes         0     No
# 20            13   45    male  23.2             85      Yes         0     No
# 56            15   23    male  28.5             88      Yes         0     No
# 98            26   47    male  32.1             81       No         0     No
# 108           15   26  female  37.4             83      Yes         0     No
# 117           27   59  female  24.1             82       No         1     No
# 161           29   21    male  31.4             91       No         1     No
# 165            9   30    male  31.1             91       No         0     No
# 245           19   23    male  31.4             88       No         1     No
# 325            5   31  female  30.2             83       No         3     No
# 377            1   57  female  34.8             96       No         1     No
# ...

# %%
s = df_duplicate_by.index
s
# Out:
# Int64Index([6, 20, 56, 98, 108, 117, 161, 165, 245, 325, 377, 454, 656, 1011,
#             1321],
#            dtype='int64')

# %%
print("Now you can delete the rows with index value ", df_duplicate_by.index,"from the original dataframe")
# Out:
# Now you can delete the rows with index value  Int64Index([6, 20, 56, 98, 108, 117, 161, 165, 245, 325, 377, 454, 656, 1011,
#             1321],
#            dtype='int64') from the original dataframe

# %%
df = df.drop(labels=s, axis=0)
df
# Out:
#       patientid  dayofmonth  age  gender   bmi  bloodpressure diabetic  \
# 0             1          19   39    male  23.2             91      Yes
# 1             2           8   24    male  30.1             87       No
# 2             3          11   27    male  33.3             82      Yes
# 3             4           5   37    male  33.7             80       No
# 4             5          21   30    male  34.1            100       No
# ...         ...         ...  ...     ...   ...            ...      ...
# 1335       1336          27   44  female  35.5             88      Yes
# 1336       1337          15   59  female  38.1            120       No
# 1337       1338          27   30    male  34.5             91      Yes
# 1338       1339          15   37    male  30.4            106       No
# 1339       1340          10   30  female  47.4            101       No
#
#       children smoker     region     claim
# 0            0     No  southeast   1121.87
# ...

# %%
df.shape
# Out:
# (1340, 11)

# %% [markdown]
# # Task-8)

# %% [markdown]
# ## Drop odd number rows from 401 to 420. Also drop the column 'dayofmonth'.
# ### First, drop odd number rows.

# %%
df = df.drop(labels=[401,403,405,407,409,411,413,415,417,419], axis=0)
df
# Out:
#       patientid  dayofmonth  age  gender   bmi  bloodpressure diabetic  \
# 0             1          19   39    male  23.2             91      Yes
# 1             2           8   24    male  30.1             87       No
# 2             3          11   27    male  33.3             82      Yes
# 3             4           5   37    male  33.7             80       No
# 4             5          21   30    male  34.1            100       No
# ...         ...         ...  ...     ...   ...            ...      ...
# 1335       1336          27   44  female  35.5             88      Yes
# 1336       1337          15   59  female  38.1            120       No
# 1337       1338          27   30    male  34.5             91      Yes
# 1338       1339          15   37    male  30.4            106       No
# 1339       1340          10   30  female  47.4            101       No
#
#       children smoker     region     claim
# 0            0     No  southeast   1121.87
# ...

# %% [markdown]
# ### Then, drop the column 'dayofmonth'.

# %%
#Dropping the column dayofmonth
df = df.drop('dayofmonth', axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [43], in <cell line: 2>()
#       1 #Dropping the column dayofmonth
# ----> 2 df = df.drop('dayofmonth', axis=1)
#       3 df.head()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %% [markdown]
# # Task-9)

# %% [markdown]
# ## Replace the values southeast, southwest, northeast and northwest by South_East, South_West, North_East and North_West respectively.

# %%
#to display full/all data [not the first five .......last five]
pd.set_option('display.max_rows',None)

# %%
df = df.replace(to_replace=['southeast', 'southwest', 'northeast','northwest'], value=['South_East', 'South_West', 'North_East', 'North_West'])
df

# %% [markdown]
# # Task-10)

# %% [markdown]
# ## Add a new column 'High_bmi' after the column 'bmi' and follow the conditions below.
# ### (1) In 'bmi', if the value is less than or equal to 32, then assign value 'No' to 'High_bmi'.
# ### (2) In 'bmi', if the value is more than 32, then assign value 'Yes' to 'High_bmi'.

# %%
import numpy as np
df.insert(4, 'High_bmi',np.nan)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [44], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 df.insert(4, 'High_bmi',np.nan)
#       3 df.head()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4440, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4434     raise ValueError(
#    4435         "Cannot specify 'allow_duplicates=True' when "
#    4436         "'self.flags.allows_duplicate_labels' is False."
#    4437     )
#    4438 if not allow_duplicates and column in self.columns:
#    4439     # Should this be a different kind of error??
# -> 4440     raise ValueError(f"cannot insert {column}, already exists")
#    4441 if not isinstance(loc, int):
#    4442     raise TypeError("loc must be int")
#
# ValueError: cannot insert High_bmi, already exists

# %%
#Putting the values in the column 'High_bmi' based on given condition
df.loc[df['bmi'] = 32, 'High_bmi'] = 'yes'
df.loc[df['bmi'] <= 32, 'High_bmi'] = 'no'
df.head()
# Out:
#    patientid  age gender   bmi High_bmi  bloodpressure diabetic  children  \
# 0          1   39   male  23.2       No             91      Yes         0
# 1          2   24   male  30.1       No             87       No         0
# 2          3   27   male  33.3      Yes             82      Yes         0
# 3          4   37   male  33.7      Yes             80       No         0
# 4          5   30   male  34.1      Yes            100       No         0
#
#   smoker      region    claim
# 0     No  South_East  1121.87
# 1     No  South_East  1131.51
# 2     No  South_East  1135.94
# 3     No  North_West  1136.40
# 4     No  North_West  1137.01

# %% [markdown]
# # Task-11)

# %% [markdown]
# ## Group the data based on gender.

# %%
gendergroup = df.groupby(['gender'])     # Data based on gender
gendergroup

# %%
for x, y in gendergroup:
    print(x)                            # print data based on gender
    print(y)                            # print data based on gender
# Out:
# female
#       patientid  age  gender   bmi High_bmi  bloodpressure diabetic  children  \
# 24           25   50  female  20.8       No             85      Yes         0
# 26           27   36  female  26.7       No             97      Yes         0
# 28           29   58  female  31.1       No             87       No         0
# 29           30   35  female  31.4       No             93       No         0
# 33           34   52  female  36.9      Yes             81       No         0
# 34           35   43  female  38.2      Yes             86      Yes         0
# 35           36   47  female  38.3      Yes             93       No         0
# 38           39   28  female  39.2      Yes             87       No         0
# 39           40   49  female  39.8      Yes            100      Yes         0
# 40           41   29  female  40.3      Yes             94       No         0
# 61           62   32  female  17.8       No             90       No         0
# ...

# %% [markdown]
# # Task-11)

# %% [markdown]
# ## Find the total claim of insurance based on regions.

# %%
df.groupby(by='region')['claim'].sum()
# Out:
# region
# North_East    3901369.33
# North_West    4022508.23
# South_East    5719049.99
# South_West    3941218.88
# Name: claim, dtype: float64

# %% [markdown]
# # Task-12)

# %% [markdown]
# ## Find the total number of males and females in each region.

# %%
df.groupby(by=['region','gender'])['gender'].count()
# Out:
# region      gender
# North_East  female    112
#             male      119
# North_West  female    163
#             male      183
# South_East  female    223
#             male      217
# South_West  female    159
#             male      154
# Name: gender, dtype: int64

# %%
# pd.crosstab(df['region'],df['gender'],values=df['claim'],aggfunc=np.mean)

# %% [markdown]
# # Task-13)

# %% [markdown]
# ## Find the average claim of insurance for males and females in each region.

# %%
df.groupby(by=['region','gender'])['claim'].mean()  #ORELSE DESCRIBE()
# Out:
# region      gender
# North_East  female    16533.758482
#             male      17223.431765
# North_West  female    12521.504847
#             male      10887.378791
# South_East  female    11615.651794
#             male      14484.998333
# South_West  female    11230.781772
#             male      14069.840000
# Name: claim, dtype: float64

# %% [markdown]
# # Task-14)

# %% [markdown]
# ## Create a pivot table that shows the average claims for each region.

# %%
df.head()          # Input data
# Out:
#    patientid  age gender   bmi High_bmi  bloodpressure diabetic  children  \
# 0          1   39   male  23.2       No             91      Yes         0
# 1          2   24   male  30.1       No             87       No         0
# 2          3   27   male  33.3      Yes             82      Yes         0
# 3          4   37   male  33.7      Yes             80       No         0
# 4          5   30   male  34.1      Yes            100       No         0
#
#   smoker      region    claim
# 0     No  South_East  1121.87
# 1     No  South_East  1131.51
# 2     No  South_East  1135.94
# 3     No  North_West  1136.40
# 4     No  North_West  1137.01

# %%
Pvt = pd.pivot_table(df, index=['region'], values=['claim'])     # Pivot table
Pvt
# Out:
#                    claim
# region
# North_East  16889.044719
# North_West  11659.444145
# South_East  13027.448724
# South_West  12632.111795

# %% [markdown]
# # Task-15)

# %% [markdown]
# ## Create a pivot table that shows the minimum and maximum claim for each region.

# %%
Pvt1 = pd.pivot_table(df, index=['region'], values=['claim'], aggfunc='min')    # Minimum claim
Pvt1
# Out:
#               claim
# region
# North_East  1694.80
# North_West  1136.40
# South_East  1121.87
# South_West  1252.41

# %%
Pvt2 = pd.pivot_table(df, index=['region'], values=['claim'], aggfunc='max')     # Maximum claim
Pvt2
# Out:
#                claim
# region
# North_East  58571.07
# North_West  60021.40
# South_East  63770.43
# South_West  52590.83

# %% [markdown]
# # Task-16)

# %% [markdown]
# ## Create a cross table to find out the region-wise gender count.

# %%
pd.crosstab(df.region, df.gender, rownames=['region'], colnames=['gender'])
# Out:
# gender      female  male
# region
# North_East     112   119
# North_West     163   183
# South_East     223   217
# South_West     159   154

# %% [markdown]
# # Task-17)

# %% [markdown]
# ## Find out the total missing values in each column of the dataset. Then replace the missing values by appropriate values.
# ### Total missing values in each column

# %%
#Total missing values in each column
df.isnull().sum()
# Out:
# patientid        0
# age              0
# gender           0
# bmi              0
# High_bmi         0
# bloodpressure    0
# diabetic         5
# children         0
# smoker           0
# region           0
# claim            3
# dtype: int64

# %% [markdown]
# ### Count the different values of diabetic column

# %%
#Counting the different values of diabetic column
df['diabetic'].value_counts()
# Out:
# No     689
# Yes    636
# Name: diabetic, dtype: int64

# %% [markdown]
# ### Replace the missing value by the most frequent value

# %%
#replace the missing value by the most frequent value
df['diabetic'] = df['diabetic'].fillna('No')

# %% [markdown]
# ### Replace the missing value by mean value in 'claim'

# %%
#replace the missing value by the mean value
df['claim'] = df['claim'].fillna(df['claim'].mean()) #CAUSE 'CLAIM' IS NUMERICAL(CONTINOUS)

# %% [markdown]
# ### Find the total missing values in each column again

# %%
#Total missing values in each column
df.isnull().sum()
# Out:
# patientid        0
# age              0
# gender           0
# bmi              0
# High_bmi         0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           0
# claim            0
# dtype: int64

# %% [markdown]
# ### There are no missing values left.
