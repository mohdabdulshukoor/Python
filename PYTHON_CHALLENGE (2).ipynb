# %% [markdown]
# # MCQ :

# %%
q1 = str(input('''Q1.Python is which type of language?
               \na) Interpreter
               \nb) Compiler
               \nc) None of the above
               \nd) All of the above
               \nAnswer : '''))
if q1 == "a":
    print("CORRECT ANSWER")
    q1 = int(1)
else:
    print("WRONG ANSWER!")
    q1 = int(0)
    
print("*********************************************************************************************")

q2 = str(input('''Q2.What will be the value of the following Python expression? 4 + 3 % 5 : 
                \na) 7
                \nb) 2
                \nc) 4
                \nd) 1
                \nAnswer : '''))
if q2 == "a":
    print("CORRECT ANSWER")
    q2 = int(1)
else:
    print("WRONG ANSWER!")
    q2 = int(0)
    
print("*********************************************************************************************")

q3 = str(input('''Q3.Which of the following is used to define a block of code in Python language?
                \na)  Indentation
                \nb)  Key
                \nc)  Brackets
                \nd)  All of the mentioned
                \nAnswer : '''))
if q3 == "a":
    print("CORRECT ANSWER")
    q3 = int(1)
else:
    print("WRONG ANSWER!")
    q3 = int(0)
    
print("*********************************************************************************************")

q4 = str(input('''Q4.What is the order of precedence in python?
                \na) Exponential, Parentheses, Multiplication, Division, Addition, Subtraction
                \nb) Exponential, Parentheses, Division, Multiplication, Addition, Subtraction
                \nc) Parentheses, Exponential, Multiplication, Division, Subtraction, Addition
                \nd) Parentheses, Exponential, Multiplication, Division, Addition, Subtraction
                \nAnswer : '''))
if q4 == "d":
    print("CORRECT ANSWER")
    q4 = int(1)
else:
    print("WRONG ANSWER!")
    q4 = int(0)
    
print("*********************************************************************************************")

q5 = str(input('''Q5.Which of the following functions is a built-in function in python?
                \na) factorial()
                \nb) print()
                \nc) seed()
                \nd) sqrt()
                \nAnswer : '''))
if q5 == "b":
    print("CORRECT ANSWER")
    q5 = int(1)
else:
    print("WRONG ANSWER!")
    q5 = int(0)
    
print("*********************************************************************************************")

q6 = str(input('''Q6.Which one is the type of data structure in python?
                \na) Dictionary
                \nb) Int
                \nc) Float
                \nd) String
                \nAnswer : '''))
if q6 == "a":
    print("CORRECT ANSWER")
    q6 = int(1)
else:
    print("WRONG ANSWER!")
    q6 = int(0)
    
print("*********************************************************************************************")

q7 = str(input('''Q7.What will be the output of the following Python function? len(["hello",2, 4, 6]) : 
                \na) Error
                \nb) 6
                \nc) 4
                \nd) 3
                \nAnswer : '''))
if q7 == "c":
    print("CORRECT ANSWER")
    q7 = int(1)
else:
    print("WRONG ANSWER!")
    q7 = int(0)
    
print("*********************************************************************************************")

q8 = str(input('''Q8.For loop is?
                \na) Definite
                \nb) Indefinite
                \nc) Infinite
                \nd) None of the above
                \nAnswer : '''))
if q8 == "a":
    print("CORRECT ANSWER")
    q8 = int(1)
else:
    print("WRONG ANSWER!")
    q8 = int(0)
    
print("*********************************************************************************************")

q9 = str(input('''Q9.Which of the following is a Python tuple?
                \na) {1, 2, 3}
                \nb) {}
                \nc) [1, 2, 3]
                \nd) (1, 2, 3)
                \nAnswer : '''))
if q9 == "d":
    print("CORRECT ANSWER")
    q9 = int(1)
else:
    print("WRONG ANSWER!")
    q9 = int(0)
    
print("*********************************************************************************************")

q10 = str(input('''Q10.What will be the output of the following Python expression? round(4.576) : 
                \na) 4
                \nb) 4.6
                \nc) 5
                \nd) 4.5
                \nAnswer : '''))
if q10 == "c":
    print("CORRECT ANSWER")
    q10 = int(1)
else:
    print("WRONG ANSWER!")
    q10 = int(0)
    
print("*********************************************************************************************")

q = q1 + q1 + q3 + q4 + q5 + q6 + q7 + q8 + q9 + q10
print("Score : ",q,"/ 10")
# Out:
# Q1.Python is which type of language?
#
# a) Interpreter
#
# b) Compiler
#
# c) None of the above
#
# d) All of the above
#
# Answer : a
# CORRECT ANSWER
# *********************************************************************************************
# Q2.What will be the value of the following Python expression? 4 + 3 % 5 :
#
# a) 7
#
# b) 2
#
# c) 4
#
# d) 1
#
# Answer : a
# CORRECT ANSWER
# *********************************************************************************************
# Q3.Which of the following is used to define a block of code in Python language?
#
# a)  Indentation
#
# b)  Key
#
# c)  Brackets
#
# d)  All of the mentioned
#
# Answer : a
# CORRECT ANSWER
# *********************************************************************************************
# Q4.What is the order of precedence in python?
#
# a) Exponential, Parentheses, Multiplication, Division, Addition, Subtraction
#
# b) Exponential, Parentheses, Division, Multiplication, Addition, Subtraction
#
# ...
