# %%
import numpy as np
import pandas as pd

# %%
d = pd.read_csv('test_scores.csv')
d
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender                             lunch  pretest  posttest
# 0     Female                  Does not qualify     62.0      72.0
# 1     Female                  Does not qualify     66.0      79.0
# 2       Male                  Does not qualify     64.0      76.0
# 3     Female                  Does not qualify     61.0      77.0
# 4       Male                  Does not qualify     64.0      76.0
# ...      ...                               ...      ...       ...
# 2128  Female                  Does not qualify     39.0      55.0
# 2129  Female  Qualifies for reduced/free lunch     38.0      46.0
# 2130  Female  Qualifies for reduced/free lunch     45.0      51.0
# 2131    Male  Qualifies for reduced/free lunch     46.0      53.0
# 2132    Male  Qualifies for reduced/free lunch     41.0      48.0
#
# [2133 rows x 10 columns]

# %% [markdown]
# # TASK 1

# %%
d1 = d.loc[:,d.columns!='student_id']
d1
#not considering the 'student_id' column
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 0     ANKYI          Urban  Non-public       6OL        Standard  Female
# 1     ANKYI          Urban  Non-public       6OL        Standard  Female
# 2     ANKYI          Urban  Non-public       6OL        Standard    Male
# 3     ANKYI          Urban  Non-public       6OL        Standard  Female
# 4     ANKYI          Urban  Non-public       6OL        Standard    Male
# ...     ...            ...         ...       ...             ...     ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2129  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2130  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2131  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2132  ZOWMK          Urban      Public       ZBH        Standard    Male
#
#                                  lunch  pretest  posttest
# 0                     Does not qualify     62.0      72.0
# 1                     Does not qualify     66.0      79.0
# 2                     Does not qualify     64.0      76.0
# 3                     Does not qualify     61.0      77.0
# 4                     Does not qualify     64.0      76.0
# ...                                ...      ...       ...
# 2128                  Does not qualify     39.0      55.0
# 2129  Qualifies for reduced/free lunch     38.0      46.0
# 2130  Qualifies for reduced/free lunch     45.0      51.0
# 2131  Qualifies for reduced/free lunch     46.0      53.0
# 2132  Qualifies for reduced/free lunch     41.0      48.0
#
# [2133 rows x 9 columns]

# %%
d11 = d1[d1.duplicated(keep='first')]
d11
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 4     ANKYI          Urban  Non-public       6OL        Standard    Male
# 19    ANKYI          Urban  Non-public       6OL        Standard    Male
# 38    ANKYI          Urban  Non-public       ZNS        Standard  Female
# 50    CCAAW       Suburban  Non-public       2B1    Experimental    Male
# 106   CCAAW       Suburban  Non-public       PGK        Standard  Female
# ...     ...            ...         ...       ...             ...     ...
# 2058  ZOWMK          Urban      Public       Q0E    Experimental  Female
# 2067  ZOWMK          Urban      Public       Q0E    Experimental    Male
# 2070  ZOWMK          Urban      Public       Q0E    Experimental  Female
# 2080  ZOWMK          Urban      Public       QA2        Standard  Female
# 2128  ZOWMK          Urban      Public       ZBH        Standard  Female
#
#                                  lunch  pretest  posttest
# 4                     Does not qualify     64.0      76.0
# 19                    Does not qualify     64.0      73.0
# 38                    Does not qualify     59.0      69.0
# 50    Qualifies for reduced/free lunch     59.0      74.0
# 106                   Does not qualify     73.0      80.0
# ...                                ...      ...       ...
# 2058  Qualifies for reduced/free lunch     38.0      53.0
# 2067  Qualifies for reduced/free lunch     37.0      53.0
# 2070  Qualifies for reduced/free lunch     38.0      53.0
# 2080  Qualifies for reduced/free lunch     45.0      51.0
# 2128                  Does not qualify     39.0      55.0
#
# [79 rows x 9 columns]

# %%
d11.count()
# Out:
# school             79
# school_setting     79
# school_type        79
# classroom          79
# teaching_method    79
# gender             79
# lunch              79
# pretest            79
# posttest           79
# dtype: int64

# %% [markdown]
# # TASK 2

# %%
# Finding all duplicated rows on given columns : school_type, teaching_method, pretest & posttest.

d2 = d1[d1.duplicated(['school_type','teaching_method','pretest','posttest'], keep=False)]
d2
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 0     ANKYI          Urban  Non-public       6OL        Standard  Female
# 2     ANKYI          Urban  Non-public       6OL        Standard    Male
# 3     ANKYI          Urban  Non-public       6OL        Standard  Female
# 4     ANKYI          Urban  Non-public       6OL        Standard    Male
# 6     ANKYI          Urban  Non-public       6OL        Standard    Male
# ...     ...            ...         ...       ...             ...     ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2129  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2130  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2131  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2132  ZOWMK          Urban      Public       ZBH        Standard    Male
#
#                                  lunch  pretest  posttest
# 0                     Does not qualify     62.0      72.0
# 2                     Does not qualify     64.0      76.0
# 3                     Does not qualify     61.0      77.0
# 4                     Does not qualify     64.0      76.0
# 6                     Does not qualify     63.0      75.0
# ...                                ...      ...       ...
# 2128                  Does not qualify     39.0      55.0
# 2129  Qualifies for reduced/free lunch     38.0      46.0
# 2130  Qualifies for reduced/free lunch     45.0      51.0
# 2131  Qualifies for reduced/free lunch     46.0      53.0
# 2132  Qualifies for reduced/free lunch     41.0      48.0
#
# [1405 rows x 9 columns]

# %%
d2.count()
# Out:
# school             1405
# school_setting     1405
# school_type        1405
# classroom          1405
# teaching_method    1405
# gender             1399
# lunch              1405
# pretest            1405
# posttest           1405
# dtype: int64

# %% [markdown]
# # TASK 3

# %%
d3 = d.groupby(by=['school'])['pretest'].mean()
d3
# Out:
# school
# ANKYI    61.341463
# CCAAW    64.623853
# CIMBB    65.067568
# CUQAM    53.925234
# DNQDD    54.327869
# FBUMG    62.891304
# GJJHK    53.194915
# GOKXL    50.796875
# GOOBU    38.248408
# IDGFP    75.202128
# KFZMY    41.865385
# KZKKE    37.261261
# LAYPA    62.035088
# OJOBU    56.197531
# QOQTS    52.527027
# UAGPU    62.390805
# UKPGS    78.453125
# UUUQX    67.253012
# VHDHF    52.666667
# VKWQH    52.060000
# VVTVA    35.955752
# ZMNYA    68.130435
# ZOWMK    41.572650
# Name: pretest, dtype: float64

# %% [markdown]
# # TASK 4

# %%
d4 = pd.crosstab(d1.school, d1.gender, rownames=['school'], colnames=['gender'])
d4
# Out:
# gender  Female  Male
# school
# ANKYI       20    21
# CCAAW       69    40
# CIMBB       36    36
# CUQAM       43    63
# DNQDD       53    69
# FBUMG       18    27
# GJJHK       64    54
# GOKXL       26    37
# GOOBU       79    78
# IDGFP       43    51
# KFZMY       28    24
# KZKKE       51    59
# LAYPA       33    24
# OJOBU       27    54
# QOQTS       76    73
# UAGPU       44    43
# UKPGS       66    61
# UUUQX       41    43
# VHDHF       24    27
# VKWQH       49    51
# VVTVA       63    49
# ZMNYA       31    38
# ZOWMK       68    49

# %% [markdown]
# # TASK 5

# %%
d51 = pd.pivot_table(d1, index=['school'], values=['posttest'], aggfunc='min')
d51
# Out:
#         posttest
# school
# ANKYI       63.0
# CCAAW       67.0
# CIMBB       64.0
# CUQAM       56.0
# DNQDD       49.0
# FBUMG       68.0
# GJJHK       49.0
# GOKXL       48.0
# GOOBU       32.0
# IDGFP       74.0
# KFZMY       44.0
# KZKKE       36.0
# LAYPA       63.0
# OJOBU       50.0
# QOQTS       51.0
# UAGPU       62.0
# UKPGS       82.0
# UUUQX       62.0
# VHDHF       52.0
# VKWQH       48.0
# VVTVA       39.0
# ZMNYA       66.0
# ZOWMK       43.0

# %%
d5i = d51.sort_values(by='posttest',ascending=True)
d5i
# Out:
#         posttest
# school
# GOOBU       32.0
# KZKKE       36.0
# VVTVA       39.0
# ZOWMK       43.0
# KFZMY       44.0
# VKWQH       48.0
# GOKXL       48.0
# DNQDD       49.0
# GJJHK       49.0
# OJOBU       50.0
# QOQTS       51.0
# VHDHF       52.0
# CUQAM       56.0
# UAGPU       62.0
# UUUQX       62.0
# LAYPA       63.0
# ANKYI       63.0
# CIMBB       64.0
# ZMNYA       66.0
# CCAAW       67.0
# FBUMG       68.0
# IDGFP       74.0
# UKPGS       82.0

# %%
#min posttest scores with school names
d5i.head()
# Out:
#         posttest
# school
# GOOBU       32.0
# KZKKE       36.0
# VVTVA       39.0
# ZOWMK       43.0
# KFZMY       44.0

# %%
d52 = pd.pivot_table(d1, index=['school'], values=['posttest'], aggfunc='max')
d52
# Out:
#         posttest
# school
# ANKYI       79.0
# CCAAW       91.0
# CIMBB       88.0
# CUQAM       76.0
# DNQDD       79.0
# FBUMG       88.0
# GJJHK       85.0
# GOKXL       77.0
# GOOBU       64.0
# IDGFP      100.0
# KFZMY       67.0
# KZKKE       62.0
# LAYPA       84.0
# OJOBU       84.0
# QOQTS       85.0
# UAGPU       83.0
# UKPGS       99.0
# UUUQX       91.0
# VHDHF       77.0
# VKWQH       82.0
# VVTVA       62.0
# ZMNYA       95.0
# ZOWMK       63.0

# %%
d52i = d51.sort_values(by='posttest',ascending=False)
d52i
# Out:
#         posttest
# school
# UKPGS       82.0
# IDGFP       74.0
# FBUMG       68.0
# CCAAW       67.0
# ZMNYA       66.0
# CIMBB       64.0
# LAYPA       63.0
# ANKYI       63.0
# UAGPU       62.0
# UUUQX       62.0
# CUQAM       56.0
# VHDHF       52.0
# QOQTS       51.0
# OJOBU       50.0
# GJJHK       49.0
# DNQDD       49.0
# GOKXL       48.0
# VKWQH       48.0
# KFZMY       44.0
# ZOWMK       43.0
# VVTVA       39.0
# KZKKE       36.0
# GOOBU       32.0

# %%
#max posttest scores with school names
d52i.head()
# Out:
#         posttest
# school
# UKPGS       82.0
# IDGFP       74.0
# FBUMG       68.0
# CCAAW       67.0
# ZMNYA       66.0

# %% [markdown]
# # TASK 6

# %%
d6 = d1[(d1.pretest>70)&(d1.posttest<80)&(d1.school_setting=='Suburban')]
d6
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 97    CCAAW       Suburban  Non-public       PGK        Standard  Female
# 111   CCAAW       Suburban  Non-public       PGK        Standard  Female
# 1449  UAGPU       Suburban      Public       S98        Standard  Female
# 1464  UAGPU       Suburban      Public       S98        Standard  Female
# 1466  UAGPU       Suburban      Public       S98        Standard    Male
# 1648  UUUQX       Suburban  Non-public       P8I        Standard  Female
# 1649  UUUQX       Suburban  Non-public       P8I        Standard  Female
# 1650  UUUQX       Suburban  Non-public       P8I        Standard  Female
# 1662  UUUQX       Suburban  Non-public       P8I        Standard    Male
# 1677  UUUQX       Suburban  Non-public       SSP        Standard  Female
# 1976  ZMNYA       Suburban      Public       4NN        Standard  Female
# 1978  ZMNYA       Suburban      Public       4NN        Standard  Female
#
#                                  lunch  pretest  posttest
# 97    Qualifies for reduced/free lunch     73.0      78.0
# 111                   Does not qualify     71.0      78.0
# 1449                  Does not qualify     73.0      79.0
# 1464                  Does not qualify     72.0      73.0
# 1466                  Does not qualify     71.0      79.0
# 1648                  Does not qualify     72.0      79.0
# 1649                  Does not qualify     71.0      76.0
# 1650                  Does not qualify     72.0      78.0
# 1662                  Does not qualify     72.0      79.0
# 1677                  Does not qualify     73.0      78.0
# 1976                  Does not qualify     74.0      72.0
# 1978                  Does not qualify     71.0      78.0

# %% [markdown]
# # TASK 7

# %%
d7i = d1.groupby(by=['school'])['pretest'].mean()
d7i
# Out:
# school
# ANKYI    61.341463
# CCAAW    64.623853
# CIMBB    65.067568
# CUQAM    53.925234
# DNQDD    54.327869
# FBUMG    62.891304
# GJJHK    53.194915
# GOKXL    50.796875
# GOOBU    38.248408
# IDGFP    75.202128
# KFZMY    41.865385
# KZKKE    37.261261
# LAYPA    62.035088
# OJOBU    56.197531
# QOQTS    52.527027
# UAGPU    62.390805
# UKPGS    78.453125
# UUUQX    67.253012
# VHDHF    52.666667
# VKWQH    52.060000
# VVTVA    35.955752
# ZMNYA    68.130435
# ZOWMK    41.572650
# Name: pretest, dtype: float64

# %%
d7iii = d7i.sort_values(axis=0,ascending=False)
print(d7iii)

d7iv=d7iii.head()
print(d7iv)
# Out:
# school
# UKPGS    78.453125
# IDGFP    75.202128
# ZMNYA    68.130435
# UUUQX    67.253012
# CIMBB    65.067568
# CCAAW    64.623853
# FBUMG    62.891304
# UAGPU    62.390805
# LAYPA    62.035088
# ANKYI    61.341463
# OJOBU    56.197531
# DNQDD    54.327869
# CUQAM    53.925234
# GJJHK    53.194915
# VHDHF    52.666667
# QOQTS    52.527027
# VKWQH    52.060000
# GOKXL    50.796875
# KFZMY    41.865385
# ZOWMK    41.572650
# GOOBU    38.248408
# KZKKE    37.261261
# VVTVA    35.955752
# Name: pretest, dtype: float64
# school
# UKPGS    78.453125
# IDGFP    75.202128
# ZMNYA    68.130435
# UUUQX    67.253012
# CIMBB    65.067568
# Name: pretest, dtype: float64

# %%
d7ii = d1.groupby(by=['school'])['pretest'].sum()
print(d7ii)
# Out:
# school
# ANKYI     2515.0
# CCAAW     7044.0
# CIMBB     4815.0
# CUQAM     5770.0
# DNQDD     6628.0
# FBUMG     2893.0
# GJJHK     6277.0
# GOKXL     3251.0
# GOOBU     6005.0
# IDGFP     7069.0
# KFZMY     2177.0
# KZKKE     4136.0
# LAYPA     3536.0
# OJOBU     4552.0
# QOQTS     7774.0
# UAGPU     5428.0
# UKPGS    10042.0
# UUUQX     5582.0
# VHDHF     2686.0
# VKWQH     5206.0
# VVTVA     4063.0
# ZMNYA     4701.0
# ZOWMK     4864.0
# Name: pretest, dtype: float64

# %% [markdown]
# # TASK 8

# %%
d8 = d1[(d1.school=='FBUMG')&(d1.classroom=='5LQ')]
print(d8)
# Out:
#     school school_setting school_type classroom teaching_method  gender  \
# 467  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 468  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 469  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 470  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 471  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 472  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 473  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 474  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 475  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 476  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 477  FBUMG          Rural  Non-public       5LQ    Experimental     NaN
# 478  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 479  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 480  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 481  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 482  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 483  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 484  FBUMG          Rural  Non-public       5LQ    Experimental    Male
#
#                                 lunch  pretest  posttest
# 467  Qualifies for reduced/free lunch     63.0      84.0
# 468  Qualifies for reduced/free lunch     68.0      85.0
# 469  Qualifies for reduced/free lunch     66.0      81.0
# 470                  Does not qualify     68.0      88.0
# 471                  Does not qualify     66.0      81.0
# 472                  Does not qualify     68.0      82.0
# 473  Qualifies for reduced/free lunch     68.0      79.0
# 474                  Does not qualify     69.0      83.0
# 475                  Does not qualify     66.0      83.0
# 476  Qualifies for reduced/free lunch     65.0      83.0
# 477                  Does not qualify     58.0      80.0
# 478                  Does not qualify     59.0      81.0
# 479                  Does not qualify     73.0      82.0
# 480                  Does not qualify     67.0      86.0
# 481                  Does not qualify     72.0      83.0
# 482  Qualifies for reduced/free lunch     56.0      73.0
# 483                  Does not qualify     61.0      76.0
# 484                  Does not qualify     68.0      87.0

# %%
d8.insert(2,'schloraship',np.nan)

# %%
d8.head()
# Out:
#     school school_setting  schloraship school_type classroom teaching_method  \
# 467  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 468  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 469  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 470  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 471  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
#
#      gender                             lunch  pretest  posttest
# 467  Female  Qualifies for reduced/free lunch     63.0      84.0
# 468  Female  Qualifies for reduced/free lunch     68.0      85.0
# 469    Male  Qualifies for reduced/free lunch     66.0      81.0
# 470    Male                  Does not qualify     68.0      88.0
# 471  Female                  Does not qualify     66.0      81.0

# %%
d8
# Out:
#     school school_setting  schloraship school_type classroom teaching_method  \
# 467  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 468  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 469  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 470  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 471  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 472  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 473  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 474  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 475  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 476  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 477  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 478  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 479  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 480  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 481  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 482  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 483  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 484  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
#
#      gender                             lunch  pretest  posttest
# 467  Female  Qualifies for reduced/free lunch     63.0      84.0
# 468  Female  Qualifies for reduced/free lunch     68.0      85.0
# 469    Male  Qualifies for reduced/free lunch     66.0      81.0
# 470    Male                  Does not qualify     68.0      88.0
# 471  Female                  Does not qualify     66.0      81.0
# 472  Female                  Does not qualify     68.0      82.0
# 473    Male  Qualifies for reduced/free lunch     68.0      79.0
# 474    Male                  Does not qualify     69.0      83.0
# 475  Female                  Does not qualify     66.0      83.0
# 476    Male  Qualifies for reduced/free lunch     65.0      83.0
# 477     NaN                  Does not qualify     58.0      80.0
# 478    Male                  Does not qualify     59.0      81.0
# 479  Female                  Does not qualify     73.0      82.0
# 480    Male                  Does not qualify     67.0      86.0
# 481    Male                  Does not qualify     72.0      83.0
# 482  Female  Qualifies for reduced/free lunch     56.0      73.0
# 483    Male                  Does not qualify     61.0      76.0
# 484    Male                  Does not qualify     68.0      87.0

# %%
d8.drop('schloraship',axis=1)
# Out:
#     school school_setting school_type classroom teaching_method  gender  \
# 467  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 468  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 469  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 470  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 471  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 472  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 473  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 474  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 475  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 476  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 477  FBUMG          Rural  Non-public       5LQ    Experimental     NaN
# 478  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 479  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 480  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 481  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 482  FBUMG          Rural  Non-public       5LQ    Experimental  Female
# 483  FBUMG          Rural  Non-public       5LQ    Experimental    Male
# 484  FBUMG          Rural  Non-public       5LQ    Experimental    Male
#
#                                 lunch  pretest  posttest
# 467  Qualifies for reduced/free lunch     63.0      84.0
# 468  Qualifies for reduced/free lunch     68.0      85.0
# 469  Qualifies for reduced/free lunch     66.0      81.0
# 470                  Does not qualify     68.0      88.0
# 471                  Does not qualify     66.0      81.0
# 472                  Does not qualify     68.0      82.0
# 473  Qualifies for reduced/free lunch     68.0      79.0
# 474                  Does not qualify     69.0      83.0
# 475                  Does not qualify     66.0      83.0
# 476  Qualifies for reduced/free lunch     65.0      83.0
# 477                  Does not qualify     58.0      80.0
# 478                  Does not qualify     59.0      81.0
# 479                  Does not qualify     73.0      82.0
# 480                  Does not qualify     67.0      86.0
# 481                  Does not qualify     72.0      83.0
# 482  Qualifies for reduced/free lunch     56.0      73.0
# 483                  Does not qualify     61.0      76.0
# 484                  Does not qualify     68.0      87.0

# %%
#Putting the values in the column 'High_bmi' based on given condition
d8.loc[d8['posttest'] == 100, 'Scholarship'] = '10000'
d8.loc[d8['posttest'] > 50, 'Scholarship'] = '5000'
d8.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4932\2112434571.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d8.loc[d8['posttest'] == 100, 'Scholarship'] = '10000'
#     school school_setting  schloraship school_type classroom teaching_method  \
# 467  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 468  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 469  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 470  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
# 471  FBUMG          Rural          NaN  Non-public       5LQ    Experimental
#
#      gender                             lunch  pretest  posttest Scholarship
# 467  Female  Qualifies for reduced/free lunch     63.0      84.0        5000
# 468  Female  Qualifies for reduced/free lunch     68.0      85.0        5000
# 469    Male  Qualifies for reduced/free lunch     66.0      81.0        5000
# 470    Male                  Does not qualify     68.0      88.0        5000
# 471  Female                  Does not qualify     66.0      81.0        5000

# %% [markdown]
# # TASK 9

# %%
d9 = d1[(d1.gender=='Female')&(d1.posttest>80)&(d1.pretest>75)]
d9
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 70    CCAAW       Suburban  Non-public       EPS    Experimental  Female
# 99    CCAAW       Suburban  Non-public       PGK        Standard  Female
# 861   IDGFP          Urban  Non-public       98D    Experimental  Female
# 869   IDGFP          Urban  Non-public       98D    Experimental  Female
# 870   IDGFP          Urban  Non-public       98D    Experimental  Female
# ...     ...            ...         ...       ...             ...     ...
# 1623  UUUQX       Suburban  Non-public       AE1    Experimental  Female
# 1993  ZMNYA       Suburban      Public       V77    Experimental  Female
# 1996  ZMNYA       Suburban      Public       V77    Experimental  Female
# 2003  ZMNYA       Suburban      Public       V77    Experimental  Female
# 2008  ZMNYA       Suburban      Public       V77    Experimental  Female
#
#                  lunch  pretest  posttest
# 70    Does not qualify     76.0      84.0
# 99    Does not qualify     78.0      84.0
# 861   Does not qualify     82.0      93.0
# 869   Does not qualify     78.0      91.0
# 870   Does not qualify     79.0      99.0
# ...                ...      ...       ...
# 1623  Does not qualify     78.0      87.0
# 1993  Does not qualify     79.0      94.0
# 1996  Does not qualify     77.0      89.0
# 2003  Does not qualify     79.0      93.0
# 2008  Does not qualify     79.0      94.0
#
# [64 rows x 9 columns]

# %%
d9i = d9.loc[0::,['student_id','school']]
d9i.groupby(by='school')['student_id'].count()

# %% [markdown]
# #  TASK 10

# %%
dx=d1[(d1.posttest<38) & (d1.pretest<50) & (d1.gender=='Male')]
dx
# Out:
#      school school_setting school_type classroom teaching_method gender  \
# 751   GOOBU          Urban      Public       HKF        Standard   Male
# 1023  KZKKE          Rural      Public       3D0        Standard   Male
# 1089  KZKKE          Rural      Public       QTU        Standard   Male
#
#                                  lunch  pretest  posttest
# 751   Qualifies for reduced/free lunch     26.0      34.0
# 1023  Qualifies for reduced/free lunch     31.0      37.0
# 1089  Qualifies for reduced/free lunch     26.0      37.0

# %%
xd = dx.index
xd
# Out:
# Int64Index([751, 1023, 1089], dtype='int64')

# %%
d1 = d1.drop(labels = xd,axis = 0)
d1

# NOTE : BECAUSE OF DOUBLE EXECUTION IT'S SHOWING AN ERROR!!!!
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 d1 = d1.drop(labels = xd,axis = 0)
#       2 d1
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: '[751, 1023, 1089] not found in axis'

# %% [markdown]
# # TASK 11

# %%
d1 = d1.replace(to_replace=['Does not qualify','Qualifies for reduced/free lunch'], value=['No','Yes'])
d1[:5]

# or d1.head()
# Out:
#   school school_setting school_type classroom teaching_method  gender lunch  \
# 0  ANKYI          Urban  Non-public       6OL        Standard  Female    No
# 1  ANKYI          Urban  Non-public       6OL        Standard  Female    No
# 2  ANKYI          Urban  Non-public       6OL        Standard    Male    No
# 3  ANKYI          Urban  Non-public       6OL        Standard  Female    No
# 4  ANKYI          Urban  Non-public       6OL        Standard    Male    No
#
#    pretest  posttest
# 0     62.0      72.0
# 1     66.0      79.0
# 2     64.0      76.0
# 3     61.0      77.0
# 4     64.0      76.0

# %% [markdown]
# # TASK 12

# %%
d12 = pd.crosstab(d1.school_setting,d1.teaching_method,rownames=['school_setting'],colnames=['teaching_method'])
d12

# or wise versa.................................................................................................

#d12 = pd.crosstab(d1.teaching_method,d1.school_setting,rownames=['teaching_method'],colnames=['school_setting'])
#d12
# Out:
# teaching_method  Experimental  Standard
# school_setting
# Rural                     201       307
# Suburban                  284       433
# Urban                     275       630

# %% [markdown]
# # TASK 13

# %%
d13 = d1[(d1.gender=='Male') & (d1.posttest<39)]
d13['pretest'] = 136
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4932\3920288862.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d13['pretest'] = 136

# %%
d1[(d1.gender=='Male') & (d1.posttest<39)]=d13
d13
# Out:
#      school school_setting school_type classroom teaching_method gender lunch  \
# 742   GOOBU          Urban      Public       HKF        Standard   Male   Yes
# 745   GOOBU          Urban      Public       HKF        Standard   Male   Yes
# 1081  KZKKE          Rural      Public       QTU        Standard   Male   Yes
#
#       pretest  posttest
# 742       136      38.0
# 745       136      38.0
# 1081      136      38.0

# %% [markdown]
# # TASK 14

# %%
d14avg = (d1.posttest.mean()).round(2)
d14avg
# Out:
# 67.16

# %%
d14 = d1[(d1.posttest>d14avg)]
d14
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 0     ANKYI          Urban  Non-public       6OL        Standard  Female
# 1     ANKYI          Urban  Non-public       6OL        Standard  Female
# 2     ANKYI          Urban  Non-public       6OL        Standard    Male
# 3     ANKYI          Urban  Non-public       6OL        Standard  Female
# 4     ANKYI          Urban  Non-public       6OL        Standard    Male
# ...     ...            ...         ...       ...             ...     ...
# 2011  ZMNYA       Suburban      Public       V77    Experimental    Male
# 2012  ZMNYA       Suburban      Public       V77    Experimental    Male
# 2013  ZMNYA       Suburban      Public       V77    Experimental    Male
# 2014  ZMNYA       Suburban      Public       V77    Experimental    Male
# 2015  ZMNYA       Suburban      Public       V77    Experimental    Male
#
#      lunch  pretest  posttest
# 0       No     62.0      72.0
# 1       No     66.0      79.0
# 2       No     64.0      76.0
# 3       No     61.0      77.0
# 4       No     64.0      76.0
# ...    ...      ...       ...
# 2011    No     74.0      84.0
# 2012    No     69.0      86.0
# 2013    No     74.0      90.0
# 2014    No     70.0      87.0
# 2015    No     76.0      95.0
#
# [1078 rows x 9 columns]

# %%
d14.groupby(by=['gender'])['gender'].count()
# Out:
# gender
# Female    530
# Male      543
# Name: gender, dtype: int64

# %% [markdown]
# # TASK 15

# %%
d15suburban = d1[(d1.gender=='Male') & (d1.school_setting=='Suburban')]

# %%
dsu = (d15suburban.posttest.mean()).round(2)
dsu
# Out:
# 75.94

# %%
d15urban=d1[(d1.gender=='Male') & (d1.school_setting=='Urban')]

# %%
du = (d15urban.posttest.mean()).round(2)                      
du
# Out:
# 62.49

# %%
d15diff = ((dsu-du)/du*100).round(2)

# %%
print(" The Relative Difference between both 'Suburban & Urban located students' is :" , d15diff)
# Out:
#  The Relative Difference between both 'Suburban & Urban located students' is : 21.52

# %% [markdown]
# # TASK 16

# %%
x = d1.isnull().sum()
x
# Out:
# school             0
# school_setting     0
# school_type        0
# classroom          0
# teaching_method    0
# gender             0
# lunch              0
# pretest            4
# posttest           4
# dtype: int64

# %%
d1['gender']=d1['gender'].fillna('Male')

# %%
d1['gender'].value_counts()
# Out:
# Male      1081
# Female    1052
# Name: gender, dtype: int64
